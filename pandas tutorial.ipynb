# %%
import numpy as np

# %%
import pandas as pd

# %%
dict1 = {"name": ['kartik' , 'yash' , 'parth' , 'ansh'],
        "marks": [100,64,78,55],
         "place": ['indore','bhpl','indore', 'bhpl']}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks   place
# 0  kartik    100  indore
# 1    yash     64    bhpl
# 2   parth     78  indore
# 3    ansh     55    bhpl

# %%
df.to_csv('friendss.csv')

# %%
df.to_csv('friendss_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#      name  marks   place
# 0  kartik    100  indore
# 1    yash     64    bhpl

# %%
df.tail(2)
# Out:
#     name  marks   place
# 2  parth     78  indore
# 3   ansh     55    bhpl

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean    74.250000
# std     19.602296
# min     55.000000
# 25%     61.750000
# 50%     71.000000
# 75%     83.500000
# max    100.000000

# %%
kartik = pd.read_csv('friendss.csv')

# %%
kartik
# Out:
#    Unnamed: 0    name  marks   place
# 0           0  kartik    100  indore
# 1           1    yash     64    bhpl
# 2           2   parth     78  indore
# 3           3    ansh     55    bhpl

# %%
kartik['marks']
# Out:
# 0    100
# 1     64
# 2     78
# 3     55
# Name: marks, dtype: int64

# %%
kartik['marks'][1]=65
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14520\3752456207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kartik['marks'][1]=65

# %%
kartik
# Out:
#    Unnamed: 0    name  marks   place
# 0           0  kartik    100  indore
# 1           1    yash     65    bhpl
# 2           2   parth     78  indore
# 3           3    ansh     55    bhpl

# %%
kartik.index=['first','second','third','fourth']

# %%
kartik
# Out:
#         Unnamed: 0    name  marks   place
# first            0  kartik    100  indore
# second           1    yash     65    bhpl
# third            2   parth     78  indore
# fourth           3    ansh     55    bhpl

# %%
ser = pd.Series(np.random.rand(100))

# %%
ser
# Out:
# 0     0.996934
# 1     0.064031
# 2     0.734635
# 3     0.002058
# 4     0.746651
#         ...
# 95    0.154378
# 96    0.498200
# 97    0.860901
# 98    0.309097
# 99    0.918850
# Length: 100, dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(335,6))

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0.207088  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    0.405804  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    0.823004  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    0.331415  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    0.514270  0.553475  0.955984  0.849246  0.082772  0.491445
# ..        ...       ...       ...       ...       ...       ...
# 330  0.200332  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  0.643796  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  0.804968  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  0.352784  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  0.194667  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# dtype: object

# %%
newdf[0][0]="woww"

# %%
newdf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0      woww  0.822653  0.137181  0.728619  0.518393  0.067848
# 1  0.405804  0.911906  0.175322  0.063780  0.938341  0.396485
# 2  0.823004  0.529123  0.786748  0.463660  0.261008  0.140461
# 3  0.331415  0.219069  0.170332  0.342166  0.531615  0.595330
# 4   0.51427  0.553475  0.955984  0.849246  0.082772  0.491445

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=335, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
newdf.to_numpy()
# Out:
# array([
# **ab iski copy ban gyi ab view ni baccha**

# %%
newdf2=newdf.copy()

# %%
newdf2[0]=6666

# %%
newdf
# Out:
#         0         1         2         3         4         5
# 0    6373  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]

# %%
newdf.loc[0,0]=3234

# %%
newdf
# Out:
#         0         1         2         3         4         5
# 0    3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]

# %%
newdf.Columns=list["ABCDE"]

# %%
newdf.head()
# Out:
#       0         1         2         3         4         5
# 0  3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 1  6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2  6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3  6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4  6373  0.553475  0.955984  0.849246  0.082772  0.491445

# %%
newdf.loc[[2,3],[4,5]]
# Out:
#           4         5
# 2  0.261008  0.140461
# 3  0.531615  0.595330

# %%
newdf.loc[[2,3,4,5],:]
# Out:
#       0         1         2         3         4         5
# 2  6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3  6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4  6373  0.553475  0.955984  0.849246  0.082772  0.491445
# 5  6373  0.013909  0.079004  0.580247  0.898447  0.682551

# %%
newdf.loc[(newdf[0]<0.3) & (newdf[2]>0.1)]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []

# %%
newdf
# Out:
#         0         1         2         3         4         5
# 0    3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.5183932842127769

# %%
newdf
# Out:
#         0         1         2         3         4         5
# 0    3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]

# %%
newdf.drop(0)
# Out:
#         0         1         2         3         4         5
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# 5    6373  0.013909  0.079004  0.580247  0.898447  0.682551
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [334 rows x 6 columns]

# %%
newdf.drop([1,5],axis=0)
# Out:
#         0         1         2         3         4         5
# 0    3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# 6    6373  0.935371  0.564443  0.540385  0.135682  0.706939
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [333 rows x 6 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#         0         1         2         3         4         5
# 0    3234  0.822653  0.137181  0.728619  0.518393  0.067848
# 1    6373  0.911906  0.175322  0.063780  0.938341  0.396485
# 2    6373  0.529123  0.786748  0.463660  0.261008  0.140461
# 3    6373  0.219069  0.170332  0.342166  0.531615  0.595330
# 4    6373  0.553475  0.955984  0.849246  0.082772  0.491445
# ..    ...       ...       ...       ...       ...       ...
# 330  6373  0.429523  0.693049  0.389920  0.069597  0.148451
# 331  6373  0.971525  0.941875  0.845971  0.231869  0.419179
# 332  6373  0.054756  0.850117  0.370376  0.045955  0.744341
# 333  6373  0.742480  0.053779  0.933045  0.035228  0.672956
# 334  6373  0.827231  0.164243  0.646414  0.506458  0.182578
#
# [335 rows x 6 columns]
